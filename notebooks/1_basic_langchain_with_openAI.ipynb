# %%
## langchain Model - OpenAI
## DOTENV - it support to load enviroment variables from a .env file

# %% [markdown]
# Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
os.getenv("OPENAI_API_KEY")
# Out:
# 'sk-proj-REDACTED'

# %%
## to create the llm object so we can QaA with model
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model = "gpt-4o-mini")

# %%
res = llm.invoke("whho is the president of USA?")
print(res.content)

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model="gpt-4o-mini")

messages = [
        SystemMessage(content="you are a teacher who is teaching students about DSA and the way you explain is very simple and easy to understand"),
        HumanMessage(content="Tell me about the concept of Trees?")
    ]

response = llm.invoke(messages)
response.content
# Out:
# "Sure! Let's break down the concept of trees in a simple way.\n\n### What is a Tree?\n\nIn computer science, a **tree** is a type of data structure that resembles a real-life tree in that it has a hierarchical structure. It consists of *nodes* connected by *edges*. \n\n### Key Components of a Tree\n\n1. **Nodes**: Each element in a tree is called a node. A tree can have many nodes.\n2. **Root**: The topmost node of a tree is called the root. It has no parent.\n3. **Children**: Nodes directly connected to another node downwards are called children.\n4. **Parent**: A node is considered a parent to its child nodes.\n5. **Leaf Nodes**: Nodes that do not have any children are called leaf nodes.\n6. **Subtree**: Any node and its descendants form a subtree. You can think of it as a smaller tree within the larger tree.\n\n### Characteristics of Trees\n\n- **Hierarchical Structure**: Trees represent data in a hierarchical manner, making it easy to navigate through levels of data.\n- **Acyclic
# ...

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model= "gpt-5")

res = llm.invoke("what is the winner of ipl 2029 of India?")
res.content
# Out:
# 'There isn’t a winner for the 2029 IPL yet—the season hasn’t happened. If you meant 2019, the champions were the Mumbai Indians. Want the full list of past IPL winners?'

# %% [markdown]
# ###Connect with google gemine

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = llm.invoke("will india get more gold medals in olympics 2036 than 2028 ?")
res.content
# Out:
# "Predicting medal counts for the Olympics several years in advance is highly speculative. Many factors can influence a nation's performance, including:\n\n*   **Athlete Development:** The emergence of new talent, the continued progression of existing athletes, and the effectiveness of training programs.\n*   **Investment and Infrastructure:** Government and private sector investment in sports, facilities, and coaching.\n*   **Sports Science and Technology:** Advancements in sports science, nutrition, and equipment can provide an edge.\n*   **Host Nation Advantage (if applicable):** If India were to host in 2036, it could potentially boost their medal count due to home crowd support and focused preparation.\n*   **Global Competition:** The performance of other nations is also a crucial factor.\n*   **Unforeseen Events:** Injuries, doping scandals, or geopolitical events can impact any nation's Olympic prospects.\n\n**Regarding India specifically:**\n\nIndia has shown a growing trend i
# ...

# %% [markdown]
# connect with Hugging Face modal

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
import os

models = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACE_API_KEY")
)

# %%
llm = ChatHuggingFace(llm=models)
res = llm.invoke("Tell me about yourself?")
res.content
# Out:
# "I'm an artificial intelligence model known as a large language model (LLM) or conversational AI. I was created to assist and provide information to users through text-based conversations. I don't have a physical body or personal experiences like humans do, but I can process and generate vast amounts of data to help with a wide range of topics and questions.\n\nMy training data includes a massive corpus of text from various sources, including books, articles, research papers, and online content. This training enables me to learn patterns, relationships, and context, allowing me to generate human-like responses to user queries.\n\nSome things you can expect from our conversation:\n\n1. **Information provision**: I can provide information on various topics, including history, science, technology, art, culture, and more.\n2. **Answering questions**: I can answer questions to the best of my knowledge based on my training data.\n3. **Generating text**: I can create text based on a prompt 
# ...

# %% [markdown]
# connect with Claude model

# %%
from langchain_anthropic import ChatAnthropic
import os
llm = ChatAnthropic(model = "claude-2")
os.getenv("ANTHROPIC_API_KEY")

res = llm.invoke("Tell me about yourself?")
res.content

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
prompts = [
    ("system" , "you are python developer expert"),
    ("user" , "what is array in python?")
]

res = llm.invoke(prompts)
res.content
# Out:
# "In Python, an array is a data structure that can hold a collection of items, typically of the same type, arranged in a specific order. However, unlike other programming languages such as C++ or Java, Python does not have a built-in array type. Instead, arrays can be implemented using lists or with the help of libraries such as NumPy, which provides a powerful array object for numerical computations.\n\nHere's a brief overview of the different array-like structures in Python:\n\n1. **Lists:**\n   - Lists are the closest built-in data type in Python that resemble arrays.\n   - They are mutable, meaning you can change their content without changing their identity.\n   - Lists can hold items of different data types, which makes them quite flexible.\n   - Example:\n     ```python\n     my_list = [1, 2, 3, 4, 5]\n     ```\n\n2. **Arrays from the `array` Module:**\n   - Python has an `array` module that provides an array object, which is like a list but can hold items of only one type.\n  
# ...
