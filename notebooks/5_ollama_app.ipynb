# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="gemma2:2b")

# %%
res = llm.invoke("Hello i am Ayush and iam testing ollam api with langchain")
res.content
# Out:
# "Hi Ayush! \n\nIt's great to hear you're experimenting with the OpenLLM API (OLLam) through LangChain!  \n\nTo help me guide you, could you tell me more about what you're trying to achieve? For example:\n\n* **What specific tasks are you interested in using the OLLam API for?** Are you looking to build chatbots, question answering systems, summarization tools, or something else entirely?\n* **What have you tried so far with LangChain and the OLLam API?** Have you already encountered any challenges or specific questions about how to use them together?\n* **Are you working with a particular model from the OpenLLM platform?**  Knowing this will help me give more targeted advice.\n\nThe more information you share, the better I can assist you on your journey of exploring OLLam and LangChain! 💪 \n\n\nLooking forward to hearing your thoughts! 😊\n"
