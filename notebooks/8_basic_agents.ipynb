# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.tools import tool

# %%
@tool
def add_numbers(a: int, b: int):
    """
       it will return the sum of two numbers
       Args:
           a: first number
           b: second number
    """
    return a + b

@tool
def multiply_numbers(a: int, b: int):
    """
       it will return the multiplication of two numbers
       Args:
           a: first number
           b: second number
    """
    return a * b

@tool
def subtract_numbers(a: int, b: int):
    """
       it will return the subtraction of two numbers
       Args:
           a: first number
           b: second number
    """
    return a - b

@tool
def divide_numbers(a: int, b: int):
    """
       it will return the division of two numbers
       Args:
           a: first number
           b: second number
    """
    return a // b

# %%
add_numbers.invoke({"a": 13, "b": 23})
# Out:
# 36

# %%
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent

# %%
llm =ChatOpenAI(model="gpt-4")

# %%
agent = create_agent(
    model=llm,
    tools=[add_numbers, subtract_numbers, multiply_numbers, divide_numbers],
    system_prompt="you are the math teacher who always use agents to solve the math problems"
)

# %%
res = agent.invoke({"messages":[{"role":"user","content":"what is the multiplication of 13 and 16?"}]})

# %%
for msg in res["messages"]:
    print(msg)
    print("\n")
# Out:
# content='what is the multiplication of 13 and 16?' additional_kwargs={} response_metadata={} id='9575c751-e657-4877-8a05-21ebec7d4af8'
#
#
# ...

# %%
print(res['messages'][-1].content)
# Out:
# The multiplication of 13 and 16 is 208.
